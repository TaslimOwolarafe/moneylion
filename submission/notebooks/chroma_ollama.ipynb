# %%
from langchain.llms import Ollama
from langchain.embeddings import OllamaEmbeddings
from langchain.document_loaders import CSVLoader, PyPDFLoader
from langchain.prompts import PromptTemplate
from langchain_community.vectorstores import Chroma
from langchain.chains import LLMChain, RetrievalQA

# %%
llm = Ollama(model="llama2")

# %%
embeddings = OllamaEmbeddings(model="llama2")

# %%
dictionary = "../data/Data Dictionary.pdf"
data = "../data/data.csv"

# %%
dict_loader = PyPDFLoader(dictionary)
data_loader = CSVLoader(data)

# %%
data_docs = data_loader.load()

# %%
dict_doc = dict_loader.load()

# %%
print(len(dict_doc), dict_doc[0])
# Out:
# 1 page_content='Data\nDictionary\nColumn\nDescription\nclnt_id\nClient\nID\nbank_id\nBank\nID\nacc_id\nAccount\nID\ntxn_id\nTransaction\nID\ntxn_date\nTransaction\ndate\ndesc\nDescription\namt\nAmount\ncat\nCategory\nof\nthe\ntransaction\nmerchant\nMerchant\nof\nthe\ntransaction' metadata={'source': '../data/Data Dictionary.pdf', 'page': 0}

# %%
print(data_docs[1])
# Out:
# page_content='clnt_id: 6\nbank_id: 1\nacc_id: 1\ntxn_id: 27\ntxn_date: 31/07/2023 0:00\ndesc: CLOC Advance\namt: 6.286\ncat: Shops\nmerchant: NA' metadata={'source': '../data/data.csv', 'row': 1}

# %%
# dict_chroma_db = Chroma.from_documents(dict_doc, embeddings, persist_directory="../data/dict_chroma_db")

# %%
dict_chroma_db = Chroma(persist_directory="../data/dict_chroma_db", embedding_function=embeddings)

# %%
# data_chroma_db = Chroma.from_documents(data_docs[:100], embeddings, persist_directory="../data/100_chunk_chroma_db")

# %%
data_chroma_db = Chroma(persist_directory="../data/100_chunk_chroma_db", embedding_function=embeddings)

# %%
len(data_chroma_db)
# Out:
# 100

# %%
data_chroma_db.get()['documents']
# Out:
# ['clnt_id: 67\nbank_id: 1\nacc_id: 1\ntxn_id: 27\ntxn_date: 19/08/2023 0:00\ndesc: Apple Cash\namt: 10.836\ncat: Shops\nmerchant: Apple',
#  'clnt_id: 51\nbank_id: 1\nacc_id: 1\ntxn_id: 8\ntxn_date: 19/07/2023 0:00\ndesc: 07-18-23 VISA DIRECT CA 2990 APPLE CASH INST XFER VISA MONEY TRANSFER CREDIT\namt: 34.476\ncat: Shops\nmerchant: NA',
#  'clnt_id: 110\nbank_id: 1\nacc_id: 1\ntxn_id: 4\ntxn_date: 12/06/2023 0:00\ndesc: APPLE CASH VISA DIRECT CA 25\namt: 9.456\ncat: Shops\nmerchant: Apple',
#  'clnt_id: 87\nbank_id: 1\nacc_id: 1\ntxn_id: 126\ntxn_date: 08/09/2023 0:00\ndesc: APPLE CASH INST XFER VISA DIRECT CA\namt: 3.546\ncat: Shops\nmerchant: Apple',
#  'clnt_id: 87\nbank_id: 1\nacc_id: 1\ntxn_id: 57\ntxn_date: 31/08/2023 0:00\ndesc: APPLE CASH INST XFER 240 CA\namt: 45.31\ncat: Shops\nmerchant: Apple',
#  'clnt_id: 104\nbank_id: 1\nacc_id: 1\ntxn_id: 105\ntxn_date: 02/06/2023 0:00\ndesc: BEST BUY 1200 FLINT MI\namt: 4.666\ncat: Shops\nmerchant: Best Buy',
#  'clnt_id: 73\nbank_id: 1\nacc_id: 1\ntxn_id: 61\ntxn_date: 07/07/2023 0:00\ndesc: APPLE CASH INST XFER VISA DIRECT CA 70\namt: 25.61\ncat: Shops\nmerchant: Apple',
#  'clnt_id:
#  'clnt_id: 121\nbank_id: 1\nacc_id: 1\ntxn_id: 135\ntxn_date: 29/09/2023 0:00\ndesc: 09-28-23 VISA DIRECT CA 4104 APPLE CASH INST XFER VISA MONEY TRANSFER CREDIT\namt: 43.734\ncat: Shops\nmerchant: NA',
#  'clnt_id: 67\nbank_id: 1\nacc_id: 1\ntxn_id: 60\ntxn_date: 13/07/2023 0:00\ndesc: Apple Cash\namt: 1.95\ncat: Shops\nmerchant: Apple',
#  'clnt_id: 87\nbank_id: 1\nacc_id: 1\ntxn_id: 92\ntxn_date: 05/07/2023 0:00\ndesc: APPLE CASH INST XFER VISA DIRECT CA\namt: 63.04\ncat: Shops\nmerchant: Apple',
#  'clnt_id: 28\nbank_id: 1\nacc_id: 1\ntxn_id: 49\ntxn_date: 21/08/2023 0:00\ndesc: 1INFINITELOOP@ 08/21 #68 PMNT RCVD 1INFINITELOOP@APP 68 CA\namt: 39.4\ncat: Shops\nmerchant: 1INFINITE',
#  'clnt_id: 87\nbank_id: 1\nacc_id: 1\ntxn_id: 121\ntxn_date: 05/07/2023 0:00\ndesc: APPLE CASH INST XFER VISA DIRECT CA\namt: 33.49\ncat: Shops\nmerchant: Apple',
#  'clnt_id: 6\nbank_id: 1\nacc_id: 1\ntxn_id: 11\ntxn_date: 01/08/2023 0:00\ndesc: CLOC Advance\namt: 2.268\ncat: Shops\nmerchant: NA']

# %%
dict_chroma_db.get()
# Out:
# {'ids': ['d5859313-fef4-4da4-be12-59537cb1a52f'],
#  'embeddings': None,
#  'metadatas': [{'page': 0, 'source': '../data/Data Dictionary.pdf'}],
#  'documents': ['Data\nDictionary\nColumn\nDescription\nclnt_id\nClient\nID\nbank_id\nBank\nID\nacc_id\nAccount\nID\ntxn_id\nTransaction\nID\ntxn_date\nTransaction\ndate\ndesc\nDescription\namt\nAmount\ncat\nCategory\nof\nthe\ntransaction\nmerchant\nMerchant\nof\nthe\ntransaction'],
#  'uris': None,
#  'data': None}

# %%
data_chroma_db.persist()

# %%
dict_chroma_db.persist()

# %%
dict_retriever = dict_chroma_db.as_retriever()

# %%
data_retriever = data_chroma_db.as_retriever()

# %%
from langchain.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser

# %%
template="""
        Given these transactions: {context}
        
        for a client with clnt_id: {client_id}
        ,please answer the question: {question}
        
        Make sure you answer in a human readable sentence.
        Answer directly, don't refer to the how you answered the question.
        
        This is what each column/keyword means:
        Column ->> Description
        clnt_id ->> Client ID
        bank_id ->>  Bank ID
        acc_id ->>  Account ID
        txn_id ->> Transaction ID
        txn_date ->> Transaction date
        desc ->> Description
        amt ->> Amount
        cat ->> Category of the transaction
        merchant ->> Merchant of the transaction
        """
        
prompt = ChatPromptTemplate.from_template(template)

# %%
template="""
        You are a helpful assistant that serves as customer care service for our company.
        You asnwer their questions.
        If you don't have their answer, reply that you cannot help in the moment.
                
        You have this data about the customers, provided by the company: {context}
        
        please answer this customer's question directly to them: {question}
        Their client clnt_id: {client_id}
        
        
        Make sure you answer in one human readable sentence.
        Answer directly, like you are in charge.
        Don't add extra informations or extra questions, don't refer to your sources and don't let the customers know about the context documents in your output.
        
        This is what each column/keyword means:
        Column ->> Description
        clnt_id ->> Client ID
        bank_id ->>  Bank ID
        acc_id ->>  Account ID
        txn_id ->> Transaction ID
        txn_date ->> Transaction date
        desc ->> Description
        amt ->> Amount
        cat ->> Category of the transaction
        merchant ->> Merchant of the transaction
        """
        
prompt = ChatPromptTemplate.from_template(template)

# %%
"""
Example:
        input: How much did i spend on August 1st, 2023?
        good output: "Dear valued customer,
        According to our records, your transaction on August 1st, 2023, had a total spend of $2.252.
        Please let me know if you have any further questions or concerns."
        Bad Output: "Good afternoon, thank you for reaching out to us. Based on the information provided in your documents, 
        it appears that you spent $2.252 on August 1st, 2023. Please let me know if there's anything else I can help you with."
"""

# %%
from operator import itemgetter

def invoke_chain(question: str, client_id=6):
    chain = (
        {
            'context': itemgetter("question") | data_retriever, "question": itemgetter("question"), "client_id": itemgetter('client_id'), 
         }
        | prompt
        | llm
        | StrOutputParser()
    )
    
    return chain.invoke({
        "client_id": client_id,
        "question": question
    })

# %%
reply = invoke_chain(question="How much did I spend on August 1st, 2023?", client_id=86)
# Out:
# [chain/start] [1:chain:RunnableSequence] Entering Chain run with input:
# {
#   "client_id": 86,
#   "question": "How much did I spend on August 1st, 2023?"
# }
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableParallel<context,question,client_id>] Entering Chain run with input:
# {
#   "client_id": 86,
#   "question": "How much did I spend on August 1st, 2023?"
# }
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableParallel<context,question,client_id> > 3:chain:RunnableSequence] Entering Chain run with input:
# {
#   "client_id": 86,
#   "question": "How much did I spend on August 1st, 2023?"
# }
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableParallel<context,question,client_id> > 3:chain:RunnableSequence > 4:chain:RunnableLambda] Entering Chain run with input:
# {
#   "client_id": 86,
#   "question": "How much did I spend on August 1st, 2023?"
# }
# [chain/end] [1:chain:RunnableSequence > 2:chain:RunnableParallel<context,question,client_id> > 3:chain:RunnableSequence > 4:chain:RunnableLambda] s] Exiting Chain run with output:
# {
#   "output": "How much did I spend on August 1st, 2023?"
# }
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableParallel<context,question,client_id> > 4:chain:RunnableLambda] Entering Chain run with input:
# {
#   "client_id": 86,
#   "question": "How much did I spend on August 1st, 2023?"
# }
# [chain/end] [1:chain:RunnableSequence > 2:chain:RunnableParallel<context,question,client_id> > 4:chain:RunnableLambda] s] Exiting Chain run with output:
# {
#   "output": "How much did I spend on August 1st, 2023?"
# }
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableParallel<context,question,client_id> > 5:chain:RunnableLambda] Entering Chain run with input:
# {
#   "client_id": 86,
#   "question": "How much did I spend on August 1st, 2023?"
# }
# [chain/end] [1:chain:RunnableSequence > 2:chain:RunnableParallel<context,question,client_id> > 5:chain:RunnableLambda] s] Exiting Chain run with output:
# {
#   "output": 86
# }
# [chain/end] [1:chain:RunnableSequence > 2:chain:RunnableParallel<context,question,client_id> > 3:chain:RunnableSequence] [23.32s] Exiting Chain run with output:
# [outputs]
# [chain/end] [1:chain:RunnableSequence > 2:chain:RunnableParallel<context,question,client_id>] [23.34s] Exiting Chain run with output:
# [outputs]
# [chain/start] [1:chain:RunnableSequence > 6:prompt:ChatPromptTemplate] Entering Prompt run with input:
# [inputs]
# [chain/end] [1:chain:RunnableSequence > 6:prompt:ChatPromptTemplate] s] Exiting Prompt run with output:
# [outputs]
# [llm/start] [1:chain:RunnableSequence > 7:llm:Ollama] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: \n        You are a helpful assistant that serves as customer care service for our company.\n        You asnwer their questions.\n        If you don't have their answer, reply that you cannot help in the moment.\n                \n        This is our custmers' data: [Document(page_content='clnt_id: 104\\nbank_id: 1\\nacc_id: 1\\ntxn_id: 105\\ntxn_date: 02/06/2023 0:00\\ndesc: BEST BUY 1200 FLINT MI\\namt: 4.666\\ncat: Shops\\nmerchant: Best Buy', metadata={'row': 81, 'source': '../data/data.csv'}), Document(page_content='clnt_id: 86\\nbank_id: 1\\nacc_id: 1\\ntxn_id: 162\\ntxn_date: 01/08/2023 0:00\\ndesc: AUTOZONE 3821 S MLK J LANSING MI 08/01\\namt: 2.252\\ncat: Shops\\nmerchant: AutoZone', metadata={'row': 41, 'source': '../data/data.csv'}), Document(page_content='clnt_id: 93\\nbank_id: 1\\nacc_id: 1\\ntxn_id: 281\\ntxn_date: 28/09/2023 0:00\\ndesc: FROM BetRivers PA, RSI US\\namt: 20\\ncat: Shops\\nmerchant: NA', metadata={'row': 72, 'source': '../data/data.csv'}), Document(page_content='clnt_id: 51\\nbank_id: 1\\nacc_id: 1\\ntxn_id: 54\\ntxn_date: 07/09/2023 0:00\\ndesc: 09-06-23 VISA DIRECT CA 2990 APPLE CASH INST XFER VISA MONEY TRANSFER CREDIT\\namt: 3.94\\ncat: Shops\\nmerchant: NA', metadata={'row': 27, 'source': '../data/data.csv'})]\n        \n        please answer this customer's question directly to them: How much did I spend on August 1st, 2023?\n        Their client clnt_id: 86\n        \n        \n        Make sure you answer in one human readable sentence.\n        Answer directly, like you are in charge.\n        Don't add extra informations or extra questions, don't refer to your sources and don't let the customers know about the documents in your output.\n        \n        Example:\n        input: How much did i spend on August 1st, 2023?\n        good output: \"Dear valued customer,\n        According to our records, your transaction on August 1st, 2023, had a total spend of $2.252.\n        Please let me know if you have any further questions or concerns.\"\n        Bad Output: \"Good afternoon, thank you for reaching out to us. Based on the information provided in your documents, \n        it appears that you spent $2.252 on August 1st, 2023. Please let me know if there's anything else I can help you with.\"\n        \n        This is what each column/keyword means:\n        Column ->> Description\n        clnt_id ->> Client ID\n        bank_id ->>  Bank ID\n        acc_id ->>  Account ID\n        txn_id ->> Transaction ID\n        txn_date ->> Transaction date\n        desc ->> Description\n        amt ->> Amount\n        cat ->> Category of the transaction\n        merchant ->> Merchant of the transaction"
#   ]
# }
# [llm/end] [1:chain:RunnableSequence > 7:llm:Ollama] [478.44s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "Dear valued customer,\n\nAccording to our records, your transaction on August 1st, 2023, had a total spend of $2.252. Please let me know if you have any further questions or concerns.",
#         "generation_info": {
#           "model": "llama2",
#           "created_at": "2024-04-13T22:38:17.0396707Z",
#           "response": "",
#           "done": true,
#           "context": [
#             518,
#             25580,
#             29962,
#             3532,
#             14816,
#             29903,
#             29958,
#             5299,
#             829,
#             14816,
#             29903,
#             6778,
#             13,
#             13,
#             29950,
#             7889,
#             29901,
#             29871,
#             13,
#             4706,
#             887,
#             526,
#             263,
#             8444,
#             20255,
#             393,
#             19700,
#             408,
#             11962,
#             2562,
#             2669,
#             363,
#             1749,
#             5001,
#             29889,
#             13,
#             4706,
#             887,
#             408,
#             29876,
#             556,
#             1009,
#             5155,
#             29889,
#             13,
#             4706,
#             960,
#             366,
#             1016,
#             29915,
#             29873,
#             505,
#             1009,
#             1234,
#             29892,
#             8908,
#             393,
#             366,
#             2609,
#             1371,
#             1235,
#             592,
#             1073,
#             565,
#             727,
#             29915,
#             29879,
#             3099,
#             1683,
#             306,
#             508,
#             1371,
#             366,
#             411,
#             1213,
#             13,
#             308,
#             13,
#             4706,
#             910,
#             338,
#             825,
#             1269,
#             1897,
#             29914,
#             26766,
#             2794,
#             29901,
#             13,
#             4706,
#             12481,
#             1599,
#             29958,
#             12953,
#             13,
#             4706,
#             1067,
#             593,
#             29918,
#             333,
#             1599,
#             29958,
#             12477,
#             3553,
#             13,
#             4706,
#             9124,
#             29918,
#             333,
#             1599,
#             29958,
#             29871,
#             10253,
#             3553,
#             13,
#             4706,
#             1035,
#             29918,
#             333,
#             1599,
#             29958,
#             29871,
#             16535,
#             3553,
#             13,
#             4706,
#             25568,
#             29876,
#             29918,
#             333,
#             1599,
#             29958,
#             4103,
#             2467,
#             3553,
#             13,
#             4706,
#             25568,
#             29876,
#             29918,
#             1256,
#             1599,
#             29958,
#             4103,
#             2467,
#             2635,
#             13,
#             4706,
#             5153,
#             1599,
#             29958,
#             12953,
#             13,
#             4706,
#             626,
#             29873,
#             1599,
#             29958,
#             1913,
#             792,
#             13,
#             4706,
#             6635,
#             1599,
#             29958,
#             17943,
#             310,
#             278,
#             10804,
#             13,
#             4706,
#             29055,
#             1599,
#             29958,
#             4702,
#             13775,
#             310,
#             278,
#             10804,
#             13,
#             308,
#             518,
#             29914,
#             25580,
#             29962,
#             13,
#             29928,
#             799,
#             659,
#             6742,
#             11962,
#             29892,
#             13,
#             13,
#             7504,
#             3278,
#             304,
#             1749,
#             6475,
#             29892,
#             596,
#             10804,
#             373,
#             3111,
#             29871,
#             29896,
#             303,
#             29892,
#             29871,
#             29906,
#             29900,
#             29906,
#             29941,
#             29892,
#             750,
#             263,
#             3001,
#             18864,
#             310,
#             395,
#             29906,
#             29889,
#             29906,
#             29945,
#             29906,
#             29889,
#             3529,
#             1235,
#             592,
#             1073,
#             565,
#             366,
#             505,
#             738,
#             4340,
#             5155,
#             470,
#             21838,
#             29889
#           ],
#           "total_duration": 476379833200,
#           "load_duration": 9726400,
#           "prompt_eval_count": 988,
#           "prompt_eval_duration": 434605742000,
#           "eval_count": 54,
#           "eval_duration": 41760660000
#         },
#         "type": "Generation"
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null
# }
# [chain/start] [1:chain:RunnableSequence > 8:parser:StrOutputParser] Entering Parser run with input:
# {
#   "input": "Dear valued customer,\n\nAccording to our records, your transaction on August 1st, 2023, had a total spend of $2.252. Please let me know if you have any further questions or concerns."
# }
# [chain/end] [1:chain:RunnableSequence > 8:parser:StrOutputParser] s] Exiting Parser run with output:
# {
#   "output": "Dear valued customer,\n\nAccording to our records, your transaction on August 1st, 2023, had a total spend of $2.252. Please let me know if you have any further questions or concerns."
# }
# [chain/end] [1:chain:RunnableSequence] [501.79s] Exiting Chain run with output:
# {
#   "output": "Dear valued customer,\n\nAccording to our records, your transaction on August 1st, 2023, had a total spend of $2.252. Please let me know if you have any further questions or concerns."
# }

# %%
print(reply)
# Out:
# Dear valued customer,
#
# According to our records, your transaction on August 1st, 2023, had a total spend of $2.252.
#
# Please let me know if you have any further questions or concerns.
